# %% [markdown]
# # Livro para consulta:
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %% [markdown]
# # 1. Importando bibliotecas <a name="import"></a>
#
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # 2. Carregando o dataframe SINASC <a name="read"></a>
# <div style="text-align: right"
#
# [Voltar ao índice](#Contents)

# %%
sinasc_raw = pd.read_csv('SINASC_RO_2019.csv')
sinasc_raw.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1        2        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2        3        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3        4        ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4        5        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
#
#    munResLat munResLon  munResAlt  munResArea
# 0  -11.93554 -61.99982      338.0    7067.025
# 1  -11.93554 -61.99982      338.0    7067.025
# 2  -11.93554 -61.99982      338.0    7067.025
# 3  -12.13178 -61.85308      397.0    3958.273
# 4  -11.93554 -61.99982      338.0    7067.025
#
# [5 rows x 69 columns]

# %% [markdown]
# # Tarefa 1

# %% [markdown]
# ### 1. Idade media das mães e dos pais por município (coluna munResNome)

# %%
sinasc_mun = sinasc_raw[['munResNome', 'IDADEMAE', 'IDADEPAI']]
sinasc_res = sinasc_mun.dropna().groupby('munResNome').mean()
sinasc_res
# Out:
#                             IDADEMAE   IDADEPAI
# munResNome
# Alta Floresta D'Oeste      25.892857  29.548701
# Alto Alegre dos Parecis    24.679104  29.179104
# Alto Paraíso               22.833333  28.833333
# Alvorada D'Oeste           26.825243  30.757282
# Ariquemes                  28.133333  32.466667
# Buritis                    24.750000  30.812500
# Cabixi                     32.166667  34.333333
# Cacaulândia                31.000000  36.333333
# Cacoal                     26.978605  30.931854
# Campo Novo de Rondônia     24.900000  30.500000
# Candeias do Jamari         23.684211  29.894737
# Castanheiras               28.071429  30.392857
# Cerejeiras                 28.361111  31.652778
# Chupinguaia                26.888889  29.629630
# Colorado do Oeste          31.161290  34.354839
# Corumbiara                 29.000000  32.470588
# Costa Marques              25.250000  30.613636
# Cujubim                    27.400000  31.400000
# Espigão D'Oeste            26.808176  31.198113
# Governador Jorge Teixeira  25.555556  29.222222
# Guajará-Mirim              26.058824  30.470588
# Itapuã do Oeste            31.375000  42.500000
# Jaru                       28.450704  32.197183
# Ji-Paraná                  27.282819  31.132239
# Machadinho D'Oeste         26.048077  31.326923
# Ministro Andreazza         27.890411  33.849315
# Mirante da Serra           26.928571  32.154762
# Monte Negro                27.642857  34.678571
# Município ignorado - RO    24.000000  22.000000
# Nova Brasilândia D'Oeste   27.104167  30.520833
# Nova Mamoré                26.051282  31.692308
# Nova União                 27.371429  31.371429
# Novo Horizonte do Oeste    26.988235  31.588235
# Ouro Preto do Oeste        27.109920  31.233244
# Parecis                    26.973684  32.473684
# Pimenta Bueno              25.449807  29.745174
# Pimenteiras do Oeste       32.600000  35.600000
# Porto Velho                28.355655  32.352679
# Presidente Médici          26.170854  30.150754
# Primavera de Rondônia      28.083333  31.888889
# Rio Crespo                 26.000000  28.000000
# Rolim de Moura             26.549701  30.360479
# Santa Luzia D'Oeste        26.043956  30.703297
# Seringueiras               25.058824  30.500000
# São Felipe D'Oeste         26.979167  31.395833
# São Francisco do Guaporé   26.944444  31.638889
# São Miguel do Guaporé      27.469136  32.666667
# Teixeirópolis              27.454545  31.500000
# Theobroma                  24.916667  30.083333
# Urupá                      27.116071  31.008929
# Vale do Anari              27.133333  34.000000
# Vale do Paraíso            25.604651  29.976744
# Vilhena                    30.611765  34.152941

# %% [markdown]
# ### 2. Peso médio dos bebes por sexo que nasceram no dia do seu aniversário por faixas de escolaridade mae
# Ex: Você, aluna(o), nasceu no dia 10/01, então você precisa filtrar o conjunto de dados nessa data e calcular o peso médio dos bebês de cada sexo por faixa de escolaridade da mãe.

# %%
sinasc_data = sinasc_raw[['ESCMAE', 'DTNASC', 'SEXO', 'PESO']].copy()

# %%
sinasc_0507 = sinasc_data[sinasc_data['DTNASC']=='2019-07-05'].groupby(['ESCMAE', 'SEXO'])['PESO'].mean().to_frame()
sinasc_0507
# Out:
#                                   PESO
# ESCMAE          SEXO
# 1 a 3 anos      Masculino  3050.000000
# 12 anos ou mais Feminino   3099.166667
#                 Masculino  2875.500000
# 4 a 7 anos      Feminino   3269.500000
#                 Masculino  2990.000000
# 8 a 11 anos     Feminino   3376.875000
#                 Masculino  3325.000000

# %%
sinasc_datanasc = sinasc_data['DTNASC'][sinasc_data['DTNASC']=='2019-07-05']

# %%
sinasc_data.pivot_table(values = ['PESO'],
                     index = ['ESCMAE', 'SEXO'],
                     columns = sinasc_datanasc,
                     aggfunc ={'PESO':[('media','mean')]})
# Out:
#                                   PESO
#                                  media
# DTNASC                      2019-07-05
# ESCMAE          SEXO
# 1 a 3 anos      Masculino  3050.000000
# 12 anos ou mais Feminino   3099.166667
#                 Masculino  2875.500000
# 4 a 7 anos      Feminino   3269.500000
#                 Masculino  2990.000000
# 8 a 11 anos     Feminino   3376.875000
#                 Masculino  3325.000000

# %% [markdown]
# ### 3. Qual o municipio que nasceu menos bebe em 2019?
#     - qual a idade media, maxima, minima das maes nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_mun.munResNome.value_counts()
# Out:
# Porto Velho                  8437
# Ji-Paraná                    2182
# Ariquemes                    1729
# Vilhena                      1590
# Cacoal                       1374
# Rolim de Moura                927
# Jaru                          881
# Guajará-Mirim                 781
# Ouro Preto do Oeste           631
# Pimenta Bueno                 616
# Buritis                       583
# Machadinho D'Oeste            500
# Espigão D'Oeste               450
# Nova Mamoré                   432
# Alta Floresta D'Oeste         367
# São Miguel do Guaporé         353
# Candeias do Jamari            337
# Presidente Médici             304
# São Francisco do Guaporé      303
# Nova Brasilândia D'Oeste      261
# Cerejeiras                    237
# Costa Marques                 233
# Alto Paraíso                  226
# Colorado do Oeste             214
# Cujubim                       205
# Alvorada D'Oeste              205
# Monte Negro                   199
# Urupá                         170
# Seringueiras                  168
# Campo Novo de Rondônia        166
# Mirante da Serra              164
# Chupinguaia                   162
# Alto Alegre dos Parecis       154
# Corumbiara                    127
# Governador Jorge Teixeira     112
# Itapuã do Oeste               109
# Nova União                    104
# Santa Luzia D'Oeste            99
# Novo Horizonte do Oeste        98
# Theobroma                      97
# Vale do Anari                  93
# Ministro Andreazza             84
# Vale do Paraíso                81
# Cabixi                         80
# Cacaulândia                    75
# Teixeirópolis                  64
# São Felipe D'Oeste             54
# Rio Crespo                     50
# Parecis                        44
# Primavera de Rondônia          43
# Pimenteiras do Oeste           40
# Castanheiras                   32
# Município ignorado - RO         1
# Name: munResNome, dtype: int64

# %%
mun_menos_nasc = sinasc_mun['munResNome'][sinasc_mun['munResNome'] == 'Castanheiras']

sinasc_mun.pivot_table(values = ['IDADEMAE', 'IDADEPAI'],
                       index = mun_menos_nasc,
                       aggfunc ={'IDADEMAE':[('minimo','min'),('maximo','max'),('media','mean')],
                                 'IDADEPAI':[('minimo','min'),('maximo','max'),('media','mean')]})
# Out:
#              IDADEMAE                  IDADEPAI
#                maximo     media minimo   maximo      media minimo
# munResNome
# Castanheiras     39.0  27.28125   17.0     43.0  30.392857   17.0

# %% [markdown]
# ### 4. Qual o municipio que nasceu mais bebe no mês de março?
#     - qual a quantidade de filhos vivos media, maxima, minima nesse municipio?
#     - qual a idade media, maxima, minima dos pais nesse municipio?

# %%
sinasc_mun2 = sinasc_raw[['DTNASC', 'QTDFILVIVO', 'IDADEPAI']].copy()

# %%
sinasc_mun2['DTNASC'] = pd.to_datetime(sinasc_mun2['DTNASC'])

# %%
sinasc_mun2['MES']= sinasc_mun2['DTNASC'].dt.month

# %%
sinasc_mun2= sinasc_mun2[sinasc_mun2['MES']==3]

# %%
sinasc_mun2.pivot_table(values = ['QTDFILVIVO', 'IDADEPAI'],
                        index = sinasc_mun2['MES'],
                        aggfunc = {'QTDFILVIVO':[('minimo','min'),('maximo','max'),('media','mean')],
                                   'IDADEPAI':[('minimo','min'),('maximo','max'),('media','mean')]})
# Out:
#     IDADEPAI                   QTDFILVIVO
#       maximo      media minimo     maximo     media minimo
# MES
# 3       62.0  31.172414   16.0        9.0  1.095009    0.0

# %%
sinasc_mun2 = sinasc_raw[['munResNome', 'QTDFILVIVO', 'IDADEPAI']]
sinasc_mun2.dropna().groupby('munResNome').agg([('minimo','min'),('maximo','max'),('media','mean')])
# Out:
#                           QTDFILVIVO                  IDADEPAI         \
#                               minimo maximo     media   minimo maximo
# munResNome
# Alta Floresta D'Oeste            0.0    7.0  0.843137     17.0   58.0
# Alto Alegre dos Parecis          0.0    5.0  0.880597     16.0   50.0
# Alto Paraíso                     0.0    2.0  0.666667     21.0   49.0
# Alvorada D'Oeste                 0.0    9.0  1.019417     17.0   52.0
# Ariquemes                        0.0    4.0  1.538462     20.0   51.0
# Buritis                          0.0    3.0  1.000000     19.0   49.0
# Cabixi                           0.0    2.0  0.500000     19.0   47.0
# Cacaulândia                      0.0    2.0  0.666667     28.0   50.0
# Cacoal                           0.0    7.0  0.889065     17.0   66.0
# Campo Novo de Rondônia           0.0    2.0  1.260870     21.0   40.0
# Candeias do Jamari               0.0    3.0  1.187500     22.0   41.0
# Castanheiras                     0.0    6.0  1.178571     17.0   43.0
# Cerejeiras                       0.0    8.0  1.422535     19.0   52.0
# Chupinguaia                      0.0    2.0  0.851852     20.0   46.0
# Colorado do Oeste                0.0    2.0  0.935484     23.0   53.0
# Corumbiara                       0.0    3.0  1.000000     21.0   52.0
# Costa Marques                    0.0   14.0  1.441860     17.0   60.0
# Cujubim                          0.0    7.0  2.500000     19.0   44.0
# Espigão D'Oeste                  0.0   12.0  1.314465     16.0   86.0
# Governador Jorge Teixeira        0.0    1.0  0.444444     22.0   37.0
# Guajará-Mirim                    0.0    3.0  0.928571     19.0   44.0
# Itapuã do Oeste                  0.0    5.0  1.875000     25.0   73.0
# Jaru                             0.0    3.0  0.750000     19.0   62.0
# Ji-Paraná                        0.0    6.0  0.859903     15.0   63.0
# Machadinho D'Oeste               0.0    8.0  0.969697     17.0   53.0
# Ministro Andreazza               0.0    6.0  1.095890     21.0   55.0
# Mirante da Serra                 0.0    3.0  0.904762     20.0   56.0
# Monte Negro                      0.0    3.0  0.928571     20.0   55.0
# Município ignorado - RO          1.0    1.0  1.000000     22.0   22.0
# Nova Brasilândia D'Oeste         0.0    4.0  0.854167     20.0   48.0
# Nova Mamoré                      0.0    5.0  1.628571     20.0   43.0
# Nova União                       0.0    3.0  0.826087     18.0   53.0
# Novo Horizonte do Oeste          0.0    4.0  0.773810     20.0   56.0
# Ouro Preto do Oeste              0.0    4.0  0.783784     17.0   60.0
# Parecis                          0.0    5.0  1.342105     18.0   61.0
# Pimenta Bueno                    0.0    9.0  0.869903     16.0   70.0
# Pimenteiras do Oeste             0.0    4.0  1.400000     25.0   45.0
# Porto Velho                      0.0    7.0  0.994774     16.0   65.0
# Presidente Médici                0.0    7.0  0.969849     16.0   64.0
# Primavera de Rondônia            0.0    4.0  1.166667     21.0   44.0
# Rio Crespo                       2.0    2.0  2.000000     28.0   28.0
# Rolim de Moura                   0.0    5.0  0.833333     16.0   69.0
# Santa Luzia D'Oeste              0.0   30.0  1.164835     18.0   53.0
# Seringueiras                     0.0    5.0  0.823529     20.0   47.0
# São Felipe D'Oeste               0.0    5.0  0.808511     18.0   57.0
# São Francisco do Guaporé         0.0    3.0  0.714286     19.0   54.0
# São Miguel do Guaporé            0.0    4.0  0.765432     19.0   60.0
# Teixeirópolis                    0.0    3.0  0.818182     20.0   67.0
# Theobroma                        0.0    2.0  0.416667     23.0   45.0
# Urupá                            0.0    5.0  0.945946     17.0   48.0
# Vale do Anari                    0.0    2.0  0.933333     23.0   58.0
# Vale do Paraíso                  0.0    2.0  0.488372     18.0   51.0
# Vilhena                          0.0    4.0  0.721893     18.0   60.0
#
#
#                                media
# munResNome
# Alta Floresta D'Oeste      29.535948
# Alto Alegre dos Parecis    29.179104
# Alto Paraíso               28.833333
# Alvorada D'Oeste           30.757282
# Ariquemes                  33.153846
# Buritis                    32.469388
# Cabixi                     34.333333
# Cacaulândia                36.333333
# Cacoal                     30.931854
# Campo Novo de Rondônia     31.000000
# Candeias do Jamari         30.187500
# Castanheiras               30.392857
# Cerejeiras                 31.690141
# Chupinguaia                29.629630
# Colorado do Oeste          34.354839
# Corumbiara                 32.470588
# Costa Marques              30.813953
# Cujubim                    31.400000
# Espigão D'Oeste            31.198113
# Governador Jorge Teixeira  29.222222
# Guajará-Mirim              30.214286
# Itapuã do Oeste            42.500000
# Jaru                       32.235714
# Ji-Paraná                  31.127536
# Machadinho D'Oeste         31.323232
# Ministro Andreazza         33.849315
# Mirante da Serra           32.154762
# Monte Negro                34.678571
# Município ignorado - RO    22.000000
# Nova Brasilândia D'Oeste   30.520833
# Nova Mamoré                31.742857
# Nova União                 31.536232
# Novo Horizonte do Oeste    31.547619
# Ouro Preto do Oeste        31.235135
# Parecis                    32.473684
# Pimenta Bueno              29.739806
# Pimenteiras do Oeste       35.600000
# Porto Velho                32.653310
# Presidente Médici          30.150754
# Primavera de Rondônia      31.888889
# Rio Crespo                 28.000000
# Rolim de Moura             30.353717
# Santa Luzia D'Oeste        30.703297
# Seringueiras               30.500000
# São Felipe D'Oeste         31.042553
# São Francisco do Guaporé   31.628571
# São Miguel do Guaporé      32.666667
# Teixeirópolis              31.500000
# Theobroma                  30.083333
# Urupá                      31.063063
# Vale do Anari              34.000000
# Vale do Paraíso            29.976744
# Vilhena                    34.147929

# %% [markdown]
# ### Analise as respostas encontradas, tire algum insight delas, conte pra gente algo encontrado nos dados. Algo que você julgue relevante e novo pra você.

# %% [markdown]
# #### Alguns dados parecem inconsistentes, um exemplo é na cidade de Santa Luzia D'Oeste, o numero maximo de filhos vivos é de 30, possivelmente houve um erro na coletas dos dados, Outro dado, a média de filhos vivos na cidade de Theobroma é 0,41, onde em comparação ao município de Cujubim essa média é de 2,5.

# %% [markdown]
# Exemplo:
# - Ah, descobri que a idade mediana das mulheres que deram a luz no ano de 2019 dos municipios x é maior que y.

# %%
sinasc_raw.dtypes
# Out:
# ORIGEM          int64
# CODESTAB      float64
# CODMUNNASC      int64
# LOCNASC         int64
# IDADEMAE        int64
#                ...
# munResUf       object
# munResLat     float64
# munResLon     float64
# munResAlt     float64
# munResArea    float64
# Length: 69, dtype: object

# %%
sinasc_raw.select_dtypes(exclude=['int64','float64'])
# Out:
#                 ESCMAE         GESTACAO GRAVIDEZ    PARTO      DTNASC  \
# 0          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-19
# 1          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-21
# 2          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-02-25
# 3      12 anos ou mais  37 a 41 semanas    Única  Cesáreo  2019-03-20
# 4          8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-03-23
# ...                ...              ...      ...      ...         ...
# 27023  12 anos ou mais  32 a 36 semanas    Única  Cesáreo  2019-12-13
# 27024      8 a 11 anos  37 a 41 semanas    Única  Vaginal  2019-10-04
# 27025      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-08-02
# 27026      8 a 11 anos  32 a 36 semanas    Única  Vaginal  2019-12-23
# 27027      8 a 11 anos  37 a 41 semanas    Única  Cesáreo  2019-12-27
#
#             SEXO RACACOR  DTCADASTRO CODANOMAL VERSAOSIST   DTRECEBIM  \
# 0      Masculino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 1       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 2       Feminino  Branca  2019-03-08       NaN     3.2.01  2019-03-08
# 3       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# 4       Feminino   Parda  2019-04-03       NaN     3.2.01  2019-04-09
# ...          ...     ...         ...       ...        ...         ...
# 27023  Masculino  Branca  2020-09-28       NaN     3.2.01  2020-10-13
# 27024  Masculino  Branca  2019-10-16       NaN     3.2.01  2019-10-21
# 27025  Masculino   Parda  2019-08-07       NaN     3.2.00  2019-08-07
# 27026  Masculino   Parda  2020-01-07       NaN     3.2.00  2020-01-07
# 27027  Masculino   Parda  2020-10-15       NaN     3.2.01  2020-10-16
#
#       munResStatus munResTipo               munResNome  munResUf
# 0            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 1            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 2            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# 3            ATIVO      MUNIC  Alto Alegre dos Parecis  Rondônia
# 4            ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...            ...        ...                      ...       ...
# 27023        ATIVO      MUNIC                  Vilhena  Rondônia
# 27024        ATIVO      MUNIC              Chupinguaia  Rondônia
# 27025        ATIVO      MUNIC                  Vilhena  Rondônia
# 27026        ATIVO      MUNIC                  Vilhena  Rondônia
# 27027        ATIVO      MUNIC  Novo Horizonte do Oeste  Rondônia
#
# [27028 rows x 15 columns]

# %%
sinasc_raw.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
#        'munResUf', 'munResLat', 'munResLon', 'munResAlt', 'munResArea'],
#       dtype='object')
